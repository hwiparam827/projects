# %%
import pandas as pd 
import numpy as np 
from collections import Counter

# %%
df=pd.read_csv('cafe_df_keward.csv')

# %%
word_count_강화읍 = Counter(df['keward'][df['id'] == '강화읍'])
word_count_교동면 = Counter(df['keward'][df['id'] == '교동면'])
word_count_길상면 = Counter(df['keward'][df['id'] == '길상면'])
word_count_내가면 = Counter(df['keward'][df['id'] == '내가면'])
word_count_불은면 = Counter(df['keward'][df['id'] == '불은면'])
word_count_삼산면 = Counter(df['keward'][df['id'] == '삼산면'])
word_count_선원면 = Counter(df['keward'][df['id'] == '선원면'])
word_count_송해면 = Counter(df['keward'][df['id'] == '송해면'])
word_count_양도면 = Counter(df['keward'][df['id'] == '양도면'])
word_count_양사면 = Counter(df['keward'][df['id'] == '양사면'])
word_count_하점면 = Counter(df['keward'][df['id'] == '하점면'])
word_count_화도면 = Counter(df['keward'][df['id'] == '화도면'])

word_count_계산동 = Counter(df['keward'][df['id'] == '계산동'])
word_count_계양동 = Counter(df['keward'][df['id'] == '계양동'])
word_count_작전동 = Counter(df['keward'][df['id'] == '작전동'])
word_count_작전서운동 = Counter(df['keward'][df['id'] == '작전서운동'])
word_count_효성동 = Counter(df['keward'][df['id'] == '효성동'])

word_count_간석동 = Counter(df['keward'][df['id'] == '간석동'])
word_count_구월동 = Counter(df['keward'][df['id'] == '구월동'])
word_count_도림동 = Counter(df['keward'][df['id'] == '도림동'])
word_count_남촌도림동 = Counter(df['keward'][df['id'] == '남촌도림동'])
word_count_논현동 = Counter(df['keward'][df['id'] == '논현동'])
word_count_논현고잔동 = Counter(df['keward'][df['id'] == '논현고잔동'])
word_count_만수동 = Counter(df['keward'][df['id'] == '만수동'])
word_count_서창2동 = Counter(df['keward'][df['id'] == '서창2동'])
word_count_장수서창동 = Counter(df['keward'][df['id'] == '장수서창동'])

word_count_금창동 = Counter(df['keward'][df['id'] == '금창동'])
word_count_만석동 = Counter(df['keward'][df['id'] == '만석동'])
word_count_송림동 = Counter(df['keward'][df['id'] == '송림동'])
word_count_송현동 = Counter(df['keward'][df['id'] == '송현동'])
word_count_화수1화평동 = Counter(df['keward'][df['id'] == '화수1.화평동'])
word_count_화수동 = Counter(df['keward'][df['id'] == '화수동'])

word_count_관교동 = Counter(df['keward'][df['id'] == '관교동'])
word_count_도화동 = Counter(df['keward'][df['id'] == '도화동'])
word_count_문학동 = Counter(df['keward'][df['id'] == '문학동'])
word_count_숭의동 = Counter(df['keward'][df['id'] == '숭의동'])
word_count_용현동 = Counter(df['keward'][df['id'] == '용현동'])
word_count_주안동 = Counter(df['keward'][df['id'] == '주안동'])
word_count_학익동 = Counter(df['keward'][df['id'] == '학익동'])

word_count_갈산동 = Counter(df['keward'][df['id'] == '갈산동'])
word_count_부개동 = Counter(df['keward'][df['id'] == '부개동'])
word_count_부평동 = Counter(df['keward'][df['id'] == '부평동'])
word_count_산곡동 = Counter(df['keward'][df['id'] == '산곡동'])
word_count_삼산동 = Counter(df['keward'][df['id'] == '삼산동'])
word_count_십정동 = Counter(df['keward'][df['id'] == '십정동'])
word_count_일신동 = Counter(df['keward'][df['id'] == '일신동'])
word_count_청천동 = Counter(df['keward'][df['id'] == '청천동'])

word_count_가정동 = Counter(df['keward'][df['id'] == '가정동'])
word_count_가좌동 = Counter(df['keward'][df['id'] == '가좌동'])
word_count_검단동 = Counter(df['keward'][df['id'] == '검단동'])
word_count_검암경서동 = Counter(df['keward'][df['id'] == '검암경서동'])
word_count_당하동 = Counter(df['keward'][df['id'] == '당하동'])
word_count_마전동 = Counter(df['keward'][df['id'] == '마전동'])
word_count_불로대곡동 = Counter(df['keward'][df['id'] == '불로대곡동'])
word_count_석남동 = Counter(df['keward'][df['id'] == '석남동'])
word_count_신현원창동 = Counter(df['keward'][df['id'] == '신현원창동'])
word_count_아라동 = Counter(df['keward'][df['id'] == '아라동'])
word_count_연희동 = Counter(df['keward'][df['id'] == '연희동'])
word_count_오류왕길동 = Counter(df['keward'][df['id'] == '오류왕길동'])
word_count_원당동 = Counter(df['keward'][df['id'] == '원당동'])
word_count_청라동 = Counter(df['keward'][df['id'] == '청라동'])

word_count_동춘동 = Counter(df['keward'][df['id'] == '동춘동'])
word_count_선학동 = Counter(df['keward'][df['id'] == '선학동'])
word_count_송도동 = Counter(df['keward'][df['id'] == '송도동'])
word_count_연수동 = Counter(df['keward'][df['id'] == '연수동'])
word_count_옥련동 = Counter(df['keward'][df['id'] == '옥련동'])
word_count_청학동 = Counter(df['keward'][df['id'] == '청학동'])

word_count_백령면 = Counter(df['keward'][df['id'] == '백령면'])
word_count_북도면 = Counter(df['keward'][df['id'] == '북도면'])
word_count_영흥면 = Counter(df['keward'][df['id'] == '영흥면'])

word_count_개항동 = Counter(df['keward'][df['id'] == '개항동'])
word_count_도원동 = Counter(df['keward'][df['id'] == '도원동'])
word_count_동인천동 = Counter(df['keward'][df['id'] == '동인천동'])
word_count_신포동 = Counter(df['keward'][df['id'] == '신포동'])
word_count_신흥동 = Counter(df['keward'][df['id'] == '신흥동'])
word_count_연안동 = Counter(df['keward'][df['id'] == '연안동'])
word_count_영종동 = Counter(df['keward'][df['id'] == '영종동'])
word_count_용유동 = Counter(df['keward'][df['id'] == '용유동'])
word_count_운서동 = Counter(df['keward'][df['id'] == '운서동'])
word_count_율목동 = Counter(df['keward'][df['id'] == '율목동'])

# %%
df2=pd.read_csv('final_2.csv')

# %%
# 카운터 객체들을 리스트로 가져왔다고 가정합니다.
counter_list = [
    word_count_강화읍, word_count_교동면, word_count_길상면, word_count_내가면, word_count_불은면,
    word_count_삼산면, word_count_선원면, word_count_송해면, word_count_양도면, word_count_양사면,
    word_count_하점면, word_count_화도면, word_count_계산동, word_count_계양동, word_count_작전동,
    word_count_작전서운동, word_count_효성동, word_count_간석동, word_count_구월동, word_count_도림동,
    word_count_남촌도림동, word_count_논현동, word_count_논현고잔동, word_count_만수동, word_count_서창2동,
    word_count_장수서창동, word_count_금창동, word_count_만석동, word_count_송림동, word_count_송현동,
    word_count_화수1화평동, word_count_화수동, word_count_관교동, word_count_도화동, word_count_문학동,
    word_count_숭의동, word_count_용현동, word_count_주안동, word_count_학익동, word_count_갈산동,
    word_count_부개동, word_count_부평동, word_count_산곡동, word_count_삼산동, word_count_십정동,
    word_count_일신동, word_count_청천동, word_count_가정동, word_count_가좌동, word_count_검단동,
    word_count_검암경서동, word_count_당하동, word_count_마전동, word_count_불로대곡동, word_count_석남동,
    word_count_신현원창동, word_count_아라동, word_count_연희동, word_count_오류왕길동, word_count_원당동,
    word_count_청라동, word_count_동춘동, word_count_선학동, word_count_송도동, word_count_연수동,
    word_count_옥련동, word_count_청학동, word_count_백령면, word_count_북도면, word_count_영흥면,
    word_count_개항동, word_count_도원동, word_count_동인천동, word_count_신포동, word_count_신흥동,
    word_count_연안동, word_count_영종동, word_count_용유동, word_count_운서동, word_count_율목동
]

counter_list
# Out:
# [Counter({'커피가 맛있어요': 67,
#           '디저트가 맛있어요': 21,
#           '인테리어가 멋져요': 14,
#           '빵이 맛있어요': 9,
#           '친절해요': 4,
#           '매장이 청결해요': 4,
#           '특별한 메뉴가 있어요': 4,
#           '음료가 맛있어요': 3,
#           '대화하기 좋아요': 2,
#           '반려동물과 가기 좋아요': 1,
#           '음식이 맛있어요': 1}),
#  Counter({'커피가 맛있어요': 28,
#           '음료가 맛있어요': 17,
#           '인테리어가 멋져요': 13,
#           '친절해요': 9,
#           '특별한 메뉴가 있어요': 8,
#           '음식이 맛있어요': 8,
#           '디저트가 맛있어요': 6,
#           '빵이 맛있어요': 6,
#           '뷰가 좋아요': 4,
#           '대화하기 좋아요': 2,
#           '건강한 맛이에요': 2,
#           '메뉴 구성이 알차요': 1,
#           '반려동물과 가기 좋아요': 1,
#           '아늑해요': 1,
#           '가성비가 좋아요': 1,
#           '화장실이 깨끗해요': 1,
#           '양이 많아요': 1,
#           '컨셉이 독특해요': 1}),
#  Counter({'커피가 맛있어요': 17,
#           '디저트가 맛있어요': 12,
#           '음료가 맛있어요': 6,
#           '뷰가 좋아요': 5,
#           '인테리어가 멋져요': 2,
#           '대화하기 좋아요': 2,
#           '건강한 맛이에요': 1,
# ...
